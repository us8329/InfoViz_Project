# %% [markdown]
# #TEAM - FLYING JATT
#
# #TEAM MEMBERS :
# ###1.P.ADITHYA (RA1911027010003)
# ###2.PUJAN DEBDAS (RA1911031010016)
# ###3.UTKARSH SINHA (RA1911003010521)
# ###4.VATSAL GUPTA (RA1911030010133)

# %%
import numpy as np 
import pandas as pd
import matplotlib as mpl 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #DATA LOADING

# %%
data=pd.read_csv("/content/StudentsPerformance.csv")

# %% [markdown]
# #DATA EXPLORING

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.count()
# Out:
# gender                         1000
# race/ethnicity                 1000
# parental level of education    1000
# lunch                          1000
# test preparation course        1000
# math score                     1000
# reading score                  1000
# writing score                  1000
# dtype: int64

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
def get_grade(marks):
    if marks>=91:
        return 'O'
    elif marks>=82 and marks<91:
        return 'A+'
    elif marks >=73 and marks<82:
        return 'A'
    elif marks >=64 and marks<73:
        return 'B+'
    elif marks>=55 and marks<64:
        return 'B'
    elif marks >=46 and marks<55:
        return 'C'
    elif marks>=35 and marks<46:
        return 'C+'
    elif marks<35:
        return 'F'

# %%
data['math grade']=data['math score'].apply(get_grade)
data['reading grade']=data['reading score'].apply(get_grade)
data['writing grade']=data['writing score'].apply(get_grade)

# %%
data['average score']=data[['math score','reading score','writing score']].mean(axis=1)

# %%
def AvgGrade(AverageScore):
    if AverageScore>=91:
        return 'O'
    elif AverageScore>=82 and AverageScore<91:
        return 'A+'
    elif AverageScore >=73 and AverageScore<82:
        return 'A'
    elif AverageScore >=64 and AverageScore<73:
        return 'B+'
    elif AverageScore>=55 and AverageScore<64:
        return 'B'
    elif AverageScore >=46 and AverageScore<55:
        return 'C'
    elif AverageScore>=35 and AverageScore<46:
        return 'C+'
    elif AverageScore<35:
        return 'F'

# %%
data["Average Grade"]=data.apply(lambda x : AvgGrade(x["average score"]),axis=1)

# %%
data.groupby('gender').count()
# Out:
#         race/ethnicity  parental level of education  lunch  \
# gender
# female             518                          518    518
# male               482                          482    482
#
#         test preparation course  math score  reading score  writing score  \
# gender
# female                      518         518            518            518
# male                        482         482            482            482
#
#         math grade  reading grade  writing grade  average score  Average Grade
# gender
# female         518            518            518            518            518
# male           482            482            482            482            482

# %%
data.groupby('race/ethnicity').count()
# Out:
#                 gender  parental level of education  lunch  \
# race/ethnicity
# group A             89                           89     89
# group B            190                          190    190
# group C            319                          319    319
# group D            262                          262    262
# group E            140                          140    140
#
#                 test preparation course  math score  reading score  \
# race/ethnicity
# group A                              89          89             89
# group B                             190         190            190
# group C                             319         319            319
# group D                             262         262            262
# group E                             140         140            140
#
#                 writing score  math grade  reading grade  writing grade  \
# race/ethnicity
# group A                    89          89             89             89
# group B                   190         190            190            190
# group C                   319         319            319            319
# group D                   262         262            262            262
# group E                   140         140            140            140
#
#                 average score  Average Grade
# race/ethnicity
# group A                    89             89
# group B                   190            190
# group C                   319            319
# group D                   262            262
# group E                   140            140

# %%
data.groupby('parental level of education').count()
# Out:
#                              gender  race/ethnicity  lunch  \
# parental level of education
# associate's degree              222             222    222
# bachelor's degree               118             118    118
# high school                     196             196    196
# master's degree                  59              59     59
# some college                    226             226    226
# some high school                179             179    179
#
#                              test preparation course  math score  \
# parental level of education
# associate's degree                               222         222
# bachelor's degree                                118         118
# high school                                      196         196
# master's degree                                   59          59
# some college                                     226         226
# some high school                                 179         179
#
#                              reading score  writing score  math grade  \
# parental level of education
# associate's degree                     222            222         222
# bachelor's degree                      118            118         118
# high school                            196            196         196
# master's degree                         59             59          59
# some college                           226            226         226
# some high school                       179            179         179
#
#                              reading grade  writing grade  average score  \
# parental level of education
# associate's degree                     222            222            222
# bachelor's degree                      118            118            118
# high school                            196            196            196
# master's degree                         59             59             59
# some college                           226            226            226
# some high school                       179            179            179
#
#                              Average Grade
# parental level of education
# associate's degree                     222
# bachelor's degree                      118
# high school                            196
# master's degree                         59
# some college                           226
# some high school                       179

# %%
data.groupby('lunch').count()
# Out:
#               gender  race/ethnicity  parental level of education  \
# lunch
# free/reduced     355             355                          355
# standard         645             645                          645
#
#               test preparation course  math score  reading score  \
# lunch
# free/reduced                      355         355            355
# standard                          645         645            645
#
#               writing score  math grade  reading grade  writing grade  \
# lunch
# free/reduced            355         355            355            355
# standard                645         645            645            645
#
#               average score  Average Grade
# lunch
# free/reduced            355            355
# standard                645            645

# %%
data.groupby('test preparation course').count()
# Out:
#                          gender  race/ethnicity  parental level of education  \
# test preparation course
# completed                   358             358                          358
# none                        642             642                          642
#
#                          lunch  math score  reading score  writing score  \
# test preparation course
# completed                  358         358            358            358
# none                       642         642            642            642
#
#                          math grade  reading grade  writing grade  \
# test preparation course
# completed                       358            358            358
# none                            642            642            642
#
#                          average score  Average Grade
# test preparation course
# completed                          358            358
# none                               642            642

# %%
data.groupby('test preparation course').count()
# Out:
#                          gender  race/ethnicity  parental level of education  \
# test preparation course
# completed                   358             358                          358
# none                        642             642                          642
#
#                          lunch  math score  reading score  writing score  \
# test preparation course
# completed                  358         358            358            358
# none                       642         642            642            642
#
#                          math grade  reading grade  writing grade  \
# test preparation course
# completed                       358            358            358
# none                            642            642            642
#
#                          average score  Average Grade
# test preparation course
# completed                          358            358
# none                               642            642

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#   math grade reading grade writing grade  average score Average Grade
# 0         B+            B+             A      72.666667            B+
# 1         B+            A+            A+      82.333333            A+
# 2         A+             O             O      92.666667             O
# 3          C             B            C+      49.333333             C
# 4          A             A             A      76.333333             A

# %%
data['math grade'].value_counts()
# Out:
# B+    226
# B     206
# A     193
# C     136
# A+    104
# C+     63
# O      50
# F      22
# Name: math grade, dtype: int64

# %%
data['reading grade'].value_counts()
# Out:
# B+    226
# A     223
# B     181
# A+    148
# C     100
# O      62
# C+     45
# F      15
# Name: reading grade, dtype: int64

# %%
data['writing grade'].value_counts()
# Out:
# A     225
# B+    223
# B     161
# C     126
# A+    120
# O      68
# C+     60
# F      17
# Name: writing grade, dtype: int64

# %% [markdown]
# #SIMPLE DATA VISUALIZATION

# %% [markdown]
# ##1.Gender Proportion

# %%
gender_counts=data["gender"].value_counts()
ax=gender_counts.plot(kind='pie',
             autopct='%.1f%%',
             startangle=45,
             labels=None,
             colors=['#FF69B4','#00FFFF'])
ax.patch.set_facecolor('white')
plt.title('What is the proportion of students by gender?')
ax.set(ylabel=None)
plt.axis('equal') 
plt.legend(labels=["Female","Male"],loc="upper right",title="Gender");

# %% [markdown]
# ##2.Students v/s Race/Ethnicity

# %%
race=data['race/ethnicity'].value_counts()
ax=sns.barplot(x=race.values,y=race.index,orient='h')
ax.set_title("How many students are there by race?")
ax.set_xlabel(xlabel="Count")
ax.set_ylabel(ylabel="Race")

for index,value in enumerate(race): 
    plt.annotate(value,xy=(value-21,index),color='black')

# %% [markdown]
# ##3.Parent's Education Level

# %%
level=data['parental level of education'].value_counts()
ax=sns.barplot(x=level.index,y=level.values,palette="Set1")
ax.set_title("What is the parents' level of education?")
ax.set_xlabel(xlabel="Level of Education")
ax.set_ylabel(ylabel="Count")
plt.xticks(rotation=45)

for index,value in enumerate(level): 
    plt.annotate(value,xy=(index-0.2,value-10),color='black')

# %% [markdown]
# ##4.Parent's Education Level with grouped by their Race/Ethnicity

# %%
ax=pd.crosstab(data["race/ethnicity"],[data["parental level of education"]]).plot.bar(stacked=True,figsize=(10,7))
ax.set_title("How are race/ethnicity and parental level of education grouped?")
ax.set_xlabel(xlabel="Race")
ax.set_ylabel(ylabel="Count")
ax.set_xticklabels(ax.get_xticklabels(),rotation=0)
ax.legend(loc="upper left",title="Parental Level of Education");

# %% [markdown]
# ##5.Lunch Status

# %%
lunch_counts=data["lunch"].value_counts()
ax=lunch_counts.plot(kind='pie',
             autopct='%1.1f%%',
             startangle=45,
             labels=None,
             colors=['#9932CC','#FFA500'])
ax.patch.set_facecolor('white')
plt.title('Which lunch type is preferred?')
ax.set(ylabel=None)
plt.axis('equal') 
plt.legend(loc="upper left",labels=["Standard","Free/Reduced"],title="Lunch Type");

# %% [markdown]
# ##6.Test Preparation Course

# %%
test_preparation_counts=data["test preparation course"].value_counts()
ax=test_preparation_counts.plot(kind='pie',
             autopct='%1.1f%%',
             startangle=45,
             labels=None,
             colors=['#FF4500','#FFD700'])
ax.patch.set_facecolor('white')
plt.title('Did the students take the test preparation course?')
ax.set(ylabel=None)
plt.axis('equal') 
plt.legend(loc="upper left",labels=["None","Completed"],title="Test Preparation Course");

# %% [markdown]
# ##7.Grades Count Visualization

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#   math grade reading grade writing grade  average score Average Grade
# 0         B+            B+             A      72.666667            B+
# 1         B+            A+            A+      82.333333            A+
# 2         A+             O             O      92.666667             O
# 3          C             B            C+      49.333333             C
# 4          A             A             A      76.333333             A

# %%
math_grade=data['math grade'].value_counts()
ax=sns.barplot(x=math_grade.index,y=math_grade.values,palette="Set1")
ax.set_title("Bar Plot of Math Grades")
ax.set_xlabel(xlabel="Math Grade")
ax.set_ylabel(ylabel="Count")

for index,value in enumerate(math_grade): 
    plt.annotate(value,xy=(index-0.2,value-10),color='black')

# %%
reading_grade=data['reading grade'].value_counts()
ax=sns.barplot(x=reading_grade.index,y=reading_grade.values)
ax.set_title("Bar Plot of Reading Grades")
ax.set_xlabel(xlabel="Reading Grade")
ax.set_ylabel(ylabel="Count")

for index,value in enumerate(reading_grade): 
    plt.annotate(value,xy=(index-0.2,value-10),color='black')

# %%
writing_grade=data['writing grade'].value_counts()
ax=sns.barplot(x=writing_grade.index,y=writing_grade.values,palette="hls")
ax.set_title("Bar Plot of Reading Grades")
ax.set_xlabel(xlabel="Writing Grade")
ax.set_ylabel(ylabel="Count")

for index,value in enumerate(writing_grade): 
    plt.annotate(value,xy=(index-0.2,value-10),color='black')

# %%
Average_grade=data['Average Grade'].value_counts()
ax=sns.barplot(x=Average_grade.index,y=Average_grade.values,palette="husl")

ax.set_title("Bar Plot of Math Grades")
ax.set_xlabel(xlabel="Average Grade")
ax.set_ylabel(ylabel="Count")

for index,value in enumerate(Average_grade): 
    plt.annotate(value,xy=(index-0.2,value-10),color='black')

# %% [markdown]
# #Advance Visualization as per our Project

# %% [markdown]
# #1.Was test preparation useful in helping students achieve good grades?

# %%
groups=data.groupby(['gender','test preparation course']).size().reset_index(name="Count")
print(groups)
# Out:
#    gender test preparation course  Count
# 0  female               completed    184
# 1  female                    none    334
# 2    male               completed    174
# 3    male                    none    308

# %%
sns.catplot(x='gender',y='math score',data=data,kind='swarm',hue='test preparation course')
plt.show()

# %%
sns.catplot(x='gender',y='reading score',data=data,kind='swarm',hue='test preparation course')
plt.show()

# %%
sns.catplot(x='gender',y='writing score',data=data,kind='swarm',hue='test preparation course')
plt.show()

# %%
plt.figure(figsize=(17,7))

plt.subplot(1,3,1)
sns.barplot(x='test preparation course',y='math score',hue='gender',data=data,palette="BrBG")

plt.subplot(1,3,2)
sns.barplot(x='test preparation course',y='reading score',hue='gender',data=data,palette="husl")

plt.subplot(1,3,3)
sns.barplot(x='test preparation course',y='writing score',hue='gender',data=data,palette="hls")

plt.tight_layout()

# %% [markdown]
# ##2.Finding the affect of Parent's education on their children's grades.

# %%
plt.figure(figsize=(16,7))

plt.subplot(1,3,1)
sns.barplot(x='parental level of education',y='math score',hue='gender',data=data,palette="Blues")
plt.xticks(rotation=90)

plt.subplot(1,3,2)
sns.barplot(x='parental level of education',y='reading score',hue='gender',data=data,palette="Greens")
plt.xticks(rotation=90)

plt.subplot(1,3,3)
sns.barplot(x='parental level of education',y='writing score',hue='gender',data=data,palette="Reds")
plt.xticks(rotation=90)

plt.tight_layout()

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(16,7))
plt.subplot(1,3,1)
sns.boxplot(x ='parental level of education' ,y='math score',data=data)
plt.xticks(rotation=90)

plt.subplot(1,3,2)
sns.boxplot(x ='parental level of education' ,y='reading score',data=data)
plt.xticks(rotation=90)

plt.subplot(1,3,3)
sns.boxplot(x ='parental level of education' ,y='writing score',data=data)
plt.xticks(rotation=90)

plt.tight_layout()

# %% [markdown]
# ##Analyzing Grades

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#   math grade reading grade writing grade  average score Average Grade
# 0         B+            B+             A      72.666667            B+
# 1         B+            A+            A+      82.333333            A+
# 2         A+             O             O      92.666667             O
# 3          C             B            C+      49.333333             C
# 4          A             A             A      76.333333             A

# %%
data['reading grade'].value_counts().index
# Out:
# Index(['B+', 'A', 'B', 'A+', 'C', 'O', 'C+', 'F'], dtype='object')

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sns.countplot(x ='math grade',data=data,order=['O','A+','A','B+','B','C','C+','F'],palette='magma')
plt.title('Grade Count in Math')


plt.subplot(1,3,2)
sns.countplot(x ='reading grade',data=data,order=['O','A+','A','B+','B','C','C+','F'],palette='magma')
plt.title('Grade Count in Reading')

plt.subplot(1,3,3)
sns.countplot(x ='writing grade',data=data,order=['O','A+','A','B+','B','C','C+','F'],palette='magma')
plt.title('Grade Count in Writing')

plt.tight_layout()

# %%
labels=data['math grade'].value_counts().index
plt.pie(data['math grade'].value_counts().values,labels=labels,explode=[0.01,0.03,0.05,0.07,0.09,0.11,0.16,0.01],
        autopct='%1.1f%%',startangle=90)
plt.title('Pie Chart for Math Grade',fontsize=20,pad=40)
plt.axis('equal')
plt.legend(loc="upper left",labels=labels,title="Grades");
plt.show()

# %%
labels=data['reading grade'].value_counts().index
plt.pie(data['reading grade'].value_counts().values,labels=labels,explode=[0.01,0.03,0.05,0.07,0.09,0.11,0.16,0.01],
        autopct='%1.1f%%',startangle=90)
plt.title('Pie Chart for Reading Grade',fontsize=20,pad=40)
plt.axis('equal')
plt.legend(loc="upper left",labels=labels,title="Grades");
plt.show()

# %%
labels=data['writing grade'].value_counts().index
plt.pie(data['writing grade'].value_counts().values,labels=labels,explode=[0.01,0.03,0.05,0.07,0.09,0.11,0.16,0.01],
        autopct='%1.1f%%',startangle=90)
plt.title('Pie Chart for Writing Grade',fontsize=20,pad=40)
plt.axis('equal')
plt.legend(loc="upper left",labels=labels,title="Grades");
plt.show()

# %%
labels=data['Average Grade'].value_counts().index
plt.pie(data['Average Grade'].value_counts().values,labels=labels,explode=[0.01,0.03,0.05,0.07,0.09,0.11,0.16,0.01],
        autopct='%1.1f%%',startangle=90)
plt.title('Pie Chart for Average Grade',fontsize=20,pad=40)
plt.axis('equal')
plt.legend(loc="upper left",labels=labels,title="Grades");
plt.show()

# %% [markdown]
# ##3.Which gender did better?

# %%
def plot_sunburst_chart(subject):
    plt.figure(figsize=(10,7))
    grade_counts=pd.crosstab(data[f"{subject}"],data["gender"])
    totals_labels=grade_counts.index
    totals=grade_counts.values.sum(axis=1)
    by_gender=grade_counts.values.flatten()
    by_gender_labels=len(grade_counts) * ["F","M"]

    by_gender_colors=len(grade_counts) * ['#FF1493','#000080']
    explode=(0.3,0.3,0.3,0.3,0.3) 

    plt.pie(totals,
            labels=totals_labels,
            autopct='%1.1f%%',
            pctdistance=1.1,
            labeldistance=0.8,
            startangle=180,
            textprops={'fontsize': 10},
            radius=12)
    plt.pie(by_gender,
            labels=by_gender_labels,
            colors=by_gender_colors,
            autopct='%1.1f%%',
            pctdistance=1.15,
            labeldistance=0.8,
            startangle=180,
            textprops={'fontsize': 10,'color': 'white'},
            radius=7)

    centre_circle=plt.Circle((0,0),5,color='black',fc='white',linewidth=0)
    fig=plt.gcf()
    fig.gca().add_artist(centre_circle)
    
    plt.title(f'Which gender did better at {subject}?',fontsize=20)

    plt.axis('equal')
    plt.tight_layout()
    plt.show()

# %%
plot_sunburst_chart("math grade")

# %%
plot_sunburst_chart("reading grade")

# %%
plot_sunburst_chart("writing grade")

# %%
plot_sunburst_chart("Average Grade")

# %% [markdown]
# ##5.Does Lunch affect Studnets Scores?

# %%
sns.catplot(x='gender',y='math score',data=data,kind='box',col='lunch')
plt.show()

# %%
sns.catplot(x='gender',y='writing score',data=data,kind='box',col='lunch')
plt.show()

# %%
sns.catplot(x='gender',y='reading score',data=data,kind='box',col='lunch')
plt.show()

# %% [markdown]
# ##Miscellaneous

# %%
sns.barplot(x='race/ethnicity',y='math score',data=data,palette="pastel");

# %%
sns.barplot(x='race/ethnicity',y='reading score',data=data,palette="bright");

# %%
sns.barplot(x='race/ethnicity',y='writing score',data=data,palette="deep");

# %%
sns.barplot(x='race/ethnicity',y='average score',data=data,palette="muted");

# %% [markdown]
# #CONCLUSIONS

# %% [markdown]
# ## 1)Students with Test Preparation in general scored higher than students without one
#
#
# ##2) Math, Reading, Writing scores is found to be more where parental level of education is master's degree and lowest where parental level of high school.
#
#
# ##3) Females scored higher than males in reading and writing , but men scored higher in maths irrespective of test preparation.

# %% [markdown]
# ******
